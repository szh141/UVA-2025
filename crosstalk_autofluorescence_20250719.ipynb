# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/UVA-2025/blob/main/crosstalk_autofluorescence_20250719.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=TKZKz5dJkcs&t=1884s
# Huygens crosstalk

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import data

# Generate some sample data
a1 = data.camera()
plt.imshow(a1)
plt.show()

x = a1.flatten()
print(x)

#y = x
y = 0.2*x + np.random.randn(len(x)) * 0.5


# Create the 2D histogram
plt.hist2d(x, y, bins=50, cmap='viridis')
plt.ylim(0,250)
plt.colorbar(label='Counts')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2D Histogram')
plt.show()
# Out:
# [200 200 200 ... 151 152 149]

# %%
from skimage import io
comp = io.imread('/content/drive/MyDrive/Colab images/BPAE.jpg')

# %%
import numpy as np
comp.shape
# Out:
# (200, 250, 3)

# %%
from matplotlib import pyplot as plt
plt.imshow(comp)

# %%
a0 = comp[:,:,0]
a1 = comp[:,:,1]
a2 = comp[:,:,2]

plt.subplot(131)
plt.imshow(a0)
plt.subplot(132)
plt.imshow(a1)
plt.subplot(133)
plt.imshow(a2)
plt.show()

# %%
x = a1.flatten()
y = a2.flatten()
z = a0.flatten()

# Create the 2D histogram
plt.hist2d(x, y, bins=250, cmap='viridis')
#plt.ylim(0,250)
plt.colorbar(label='Counts')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2D Histogram')
plt.show()

plt.hist2d(x, z, bins=250, cmap='viridis')
#plt.ylim(0,250)
plt.colorbar(label='Counts')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2D Histogram')
plt.show()

plt.hist2d(z, y, bins=250, cmap='viridis')
#plt.ylim(0,250)
plt.colorbar(label='Counts')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2D Histogram')
plt.show()
